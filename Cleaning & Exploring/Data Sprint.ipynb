# %% [markdown]
# # Importing Data

# %% [markdown]
# ## 1) E-Commerce Public Dataset

# %%
import pandas as pd

# %%
customers = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_customers_dataset.csv')

# %%
orders = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_orders_dataset.csv')

# %%
locations = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_geolocation_dataset.csv')

# %%
items = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_order_items_dataset.csv')

# %%
payments = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_order_payments_dataset.csv')

# %%
reviews = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_order_reviews_dataset.csv')

# %%
products = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_products_dataset.csv')

# %%
sellers = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\olist_sellers_dataset.csv')

# %%
translation = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\product_category_name_translation.csv')

# %% [markdown]
# ## 2) Marketing Funnel by Olist

# %%
closed_deals = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\marketing\olist_closed_deals_dataset.csv')

# %%
qualified_leads = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\marketing\olist_marketing_qualified_leads_dataset.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1)Customers

# %%
customers.describe(include='object')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
#
#        customer_city customer_state
# count          99441          99441
# unique          4119             27
# top        sao paulo             SP
# freq           15540          41746

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 2) Reviews

# %%
reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
reviews.isnull().mean()*100
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 3) Orders

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders.describe(include='object')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:05:26  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
customers[customers['customer_unique_id'] == '8d50f5eadf50201ccdcedfb9e2ac8455']
# Out:
#                             customer_id                customer_unique_id  \
# 14186  1bd3585471932167ab72a84955ebefea  8d50f5eadf50201ccdcedfb9e2ac8455
# 15321  a8fabc805e9a10a3c93ae5bff642b86b  8d50f5eadf50201ccdcedfb9e2ac8455
# 16654  897b7f72042714efaa64ac306ba0cafc  8d50f5eadf50201ccdcedfb9e2ac8455
# 36122  b2b13de0770e06de50080fea77c459e6  8d50f5eadf50201ccdcedfb9e2ac8455
# 38073  42dbc1ad9d560637c9c4c1533746f86d  8d50f5eadf50201ccdcedfb9e2ac8455
# 40141  dfb941d6f7b02f57a44c3b7c3fefb44b  8d50f5eadf50201ccdcedfb9e2ac8455
# 48614  65f9db9dd07a4e79b625effa4c868fcb  8d50f5eadf50201ccdcedfb9e2ac8455
# 52574  1c62b48fb34ee043310dcb233caabd2e  8d50f5eadf50201ccdcedfb9e2ac8455
# 58707  a682769c4bc10fc6ef2101337a6c83c9  8d50f5eadf50201ccdcedfb9e2ac8455
# 67996  6289b75219d757a56c0cce8d9e427900  8d50f5eadf50201ccdcedfb9e2ac8455
# 72745  3414a9c813e3ca02504b8be8b2deb27f  8d50f5eadf50201ccdcedfb9e2ac8455
# 74510  0e4fdc084a6b9329ed55d62dcd653ccf  8d50f5eadf50201ccdcedfb9e2ac8455
# ...

# %%
qualified_leads.describe(include='object')
# Out:
#                                   mql_id first_contact_date  \
# count                               8000               8000
# unique                              8000                336
# top     dac32acd4db4c29c230538b72f8dd87d         2018-05-02
# freq                                   1                 93
#
#                          landing_page_id          origin
# count                               8000            7940
# unique                               495              10
# top     b76ef37428e6799c421989521c0e5077  organic_search
# freq                                 912            2296

# %%
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# # Recatecorization & Cleaning

# %%
len(translation['product_category_name'].unique())
# Out:
# 71

# %%
category_map = {
    'bed_bath_table': 'Home & Furniture',
    'furniture_decor': 'Home & Furniture',
    'furniture_mattress_and_upholstery': 'Home & Furniture',
    'furniture_living_room': 'Home & Furniture',
    'furniture_bedroom': 'Home & Furniture',
    'home_confort': 'Home & Furniture',
    'home_comfort_2': 'Home & Furniture',
    'home_appliances': 'Home & Furniture',
    'home_appliances_2': 'Home & Furniture',
    'kitchen_dining_laundry_garden_furniture': 'Home & Furniture',
    'housewares': 'Home & Furniture',
    'home_construction': 'Home & Furniture',
    'office_furniture': 'Home & Furniture',
     'furniture_mattress_and_upholstery': 'Home & Furniture',

    'health_beauty': 'Health & Beauty',
    'perfumery': 'Health & Beauty',
    'diapers_and_hygiene': 'Health & Beauty',

    'fashion_bags_accessories': 'Fashion & Accessories',
    'fashion_shoes': 'Fashion & Accessories',
    'fashion_male_clothing': 'Fashion & Accessories',
    'fashion_childrens_clothes': 'Fashion & Accessories',
    'fashion_underwear_beach': 'Fashion & Accessories',
    'fashion_sport': 'Fashion & Accessories',
    'fashio_female_clothing': 'Fashion & Accessories',
    'luggage_accessories': 'Fashion & Accessories',

    'computers': 'Electronics & Tech',
    'computers_accessories': 'Electronics & Tech',
    'tablets_printing_image': 'Electronics & Tech',
    'electronics': 'Electronics & Tech',
    'telephony': 'Electronics & Tech',
    'fixed_telephony': 'Electronics & Tech',
    'audio': 'Electronics & Tech',
    'consoles_games': 'Electronics & Tech',
    'cine_photo': 'Electronics & Tech',
    'cds_dvds_musicals': 'Electronics & Tech',
    'dvds_blu_ray': 'Electronics & Tech',
    'air_conditioning': 'Electronics & Tech',
    'computers': 'Electronics & Tech',


    'sports_leisure': 'Sports & Leisure',
    'cool_stuff': 'Sports & Leisure',
    'toys': 'Sports & Leisure',
    'musical_instruments': 'Sports & Leisure',
    'music': 'Sports & Leisure',
    'art': 'Sports & Leisure',
    'books_general_interest': 'Sports & Leisure',
    'books_imported': 'Sports & Leisure',
    'books_technical': 'Sports & Leisure',
    'party_supplies': 'Sports & Leisure',
    'christmas_supplies': 'Sports & Leisure',

    'construction_tools_construction': 'Tools & Industrial',
    'construction_tools_garden': 'Tools & Industrial',
    'costruction_tools_garden': 'Tools & Industrial',
    'costruction_tools_tools': 'Tools & Industrial',
    'construction_tools_lights': 'Tools & Industrial',
    'construction_tools_safety': 'Tools & Industrial',
    'signaling_and_security': 'Tools & Industrial',
    'security_and_services': 'Tools & Industrial',
    'industry_commerce_and_business': 'Tools & Industrial',
    'agro_industry_and_commerce': 'Tools & Industrial',
    'garden_tools': 'Tools & Industrial',

    'market_place': 'Marketplace & Retail',
    'stationery': 'Marketplace & Retail',
    'office_furniture': 'Marketplace & Retail',

    'baby': 'Baby, Kids & Pet',
    'pet_shop': 'Baby, Kids & Pet',

    'food': 'Food & Drinks',
    'food_drink': 'Food & Drinks',
    'drinks': 'Food & Drinks',
    'la_cuisine': 'Food & Drinks',
    'small_appliances': 'Food & Drinks',
    'small_appliances_home_oven_and_coffee': 'Food & Drinks',

    'watches_gifts': 'Gifts & Decoration',
    'flowers': 'Gifts & Decoration',
    'arts_and_craftmanship': 'Gifts & Decoration',

    'auto': 'Automotive',
}

# %%
translation['main_category'] = translation['product_category_name_english'].map(category_map)

# %%
translation.columns = ['product_category_name', 'Sub category', 'main category']

# %%
translation.to_csv('translation.csv')

# %%
products['product_category_name'].isnull().mean()
# Out:
# np.float64(0.018512336499651)

# %%
products.dropna(inplace= True)

# %%
new_rows = pd.DataFrame({
    'product_category_name': ['pc_gamer', 'moveis_colchao_e_estofado'],
    'product_category_name_english': ['computers', 'furniture_mattress_and_upholstery']
})

# Append to your main translation_df
translation = pd.concat([translation, new_rows], ignore_index=True)

# %%
translation
# Out:
#             product_category_name      product_category_name_english
# 0                    beleza_saude                      health_beauty
# 1          informatica_acessorios              computers_accessories
# 2                      automotivo                               auto
# 3                 cama_mesa_banho                     bed_bath_table
# 4                moveis_decoracao                    furniture_decor
# ..                            ...                                ...
# 68                fraldas_higiene                diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil          fashion_childrens_clothes
# 70             seguros_e_servicos              security_and_services
# 71                       pc_gamer                          computers
# 72      moveis_colchao_e_estofado  furniture_mattress_and_upholstery
#
# [73 rows x 2 columns]

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
products[products['product_id'].str.contains('980a05f1865790c75cf9a22ae4771c1c')]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
products.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
items.merge(products,how = 'left').isnull().mean()*100
# Out:
# order_id                      0.000000
# order_item_id                 0.000000
# product_id                    0.000000
# seller_id                     0.000000
# shipping_limit_date           0.000000
# price                         0.000000
# freight_value                 0.000000
# product_category_name         1.423879
# product_name_lenght           1.423879
# product_description_lenght    1.423879
# product_photos_qty            1.423879
# product_weight_g              1.423879
# product_length_cm             1.423879
# product_height_cm             1.423879
# product_width_cm              1.423879
# dtype: float64

# %%
items.dropna(inplace = True)

# %%
items.to_csv('items.csv')

# %% [markdown]
# # Reviews Categorization

# %%
#classification = ['Delivery','Deffect','Wrong Item','Missing Items','Company','Others','Positive']

# Use a pipeline as a high-level helper
# from transformers import pipeline
# pipe = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7")

#1
# def catigorized(lists):
#   n = pipe(lists[26000:30000], classification, multi_label=False)
#   pd.DataFrame(n).to_csv('catigorized.csv')
#   return n

#2
# unsorted = catigorized(comments_list)

#3
# reviews_categories = []
# for i in range(len(unsorted)):
#   reviews_categories.append(unsorted[i]['labels'][:2])

#4
# pd.DataFrame(reviews_categories).to_csv('sorted.csv')

#5
# from google.colab import files
# files.download('sorted.csv')

# %% [markdown]
# ## 1) Importing data

# %%
reviews1 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\0-1000.csv')

# %%
reviews2 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\1000-2000.csv')

# %%
reviews3 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\2000-7000.csv')

# %%
reviews4 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\7000-10000.csv')

# %%
reviews5 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\10000-13000.csv')

# %%
reviews6 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\13000 - 16000.csv')

# %%
reviews7 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\16000 - 20000.csv')

# %%
reviews8 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\20000 - 24000.csv')

# %%
reviews9 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\24000 - 26000.csv')

# %%
reviews10 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\26000-31000.csv')

# %%
reviews11 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\31000-36000.csv')

# %%
reviews12 = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\36000-40977.csv')

# %% [markdown]
# ## 2) Concatinating

# %%
category_reviews = pd.concat([reviews1,reviews2,reviews3,reviews4,reviews5,reviews6,reviews7,reviews8,reviews9,reviews10,reviews11,reviews12], ignore_index=True)

# %%
category_reviews.columns = ['index', 'Primary Category', 'Secondary Category']

# %%
category_reviews.drop('index', axis=1 , inplace=True)

# %%
category_reviews
# Out:
#       Primary Category Secondary Category
# 0              Company           Delivery
# 1             Positive           Delivery
# 2        Missing Items            Deffect
# 3        Missing Items            Deffect
# 4        Missing Items           Positive
# ...                ...                ...
# 40972         Positive      Missing Items
# 40973         Positive      Missing Items
# 40974         Positive      Missing Items
# 40975         Positive      Missing Items
# 40976         Positive      Missing Items
#
# [40977 rows x 2 columns]

# %% [markdown]
# ## 3) Merging With Reviews

# %%
concated = reviews.sort_values(by='review_comment_message',ascending=False)

# %%
concated.reset_index(inplace = True)

# %%
concated = pd.concat([concated,category_reviews],axis=1)

# %%
concated
# Out:
#        index                         review_id  \
# 0      90604  78ef188726f0bf273844e117b63e1d80
# 1      30017  f4fe6a8976ba615c00f0c5e42250d293
# 2      18496  ea70389d0aee26a9d7cb9ce3ea9a6650
# 3      34359  79c798a201538ab543bb86af0182f4c9
# 4      76390  384e5d48af46db4c863eb5d756566368
# ...      ...                               ...
# 99219  99217  c6b270c61f67c9f7cb07d84ea8aeaf8b
# 99220  99218  af2dc0519de6e0720ef0c74292fb4114
# 99221  99219  574ed12dd733e5fa530cfd4bbf39d7c9
# 99222  99220  f3897127253a9592a73be9bdfdf4ed7a
# 99223  99222  1adeb9d84d72fe4e337617733eb85149
#
#                                order_id  review_score review_comment_title  \
# 0      d05d5881240a2b6f02e90a83bddc85cd             1                  NaN
# 1      6d983186ed41c01b43e558f2d7a68010             5                  NaN
# 2      78c96fa659d86790819c423216522535             4                  NaN
# 3      83073309378cf709e67e8368e97447c4             5                  NaN
# ...

# %%
concated.drop('index', axis=1 , inplace=True)

# %%
concated.columns = ['review_id', 1,2,'review_comment_title',
       'review_comment_message', 3,4, 'Primary Category', 'Secondary Category']

# %%
concated.drop([1,2,3,4], axis=1 , inplace=True)

# %%
concated
# Out:
#                               review_id review_comment_title  \
# 0      78ef188726f0bf273844e117b63e1d80                  NaN
# 1      f4fe6a8976ba615c00f0c5e42250d293                  NaN
# 2      ea70389d0aee26a9d7cb9ce3ea9a6650                  NaN
# 3      79c798a201538ab543bb86af0182f4c9                  NaN
# 4      384e5d48af46db4c863eb5d756566368                  NaN
# ...                                 ...                  ...
# 99219  c6b270c61f67c9f7cb07d84ea8aeaf8b                  NaN
# 99220  af2dc0519de6e0720ef0c74292fb4114                  NaN
# 99221  574ed12dd733e5fa530cfd4bbf39d7c9                  NaN
# 99222  f3897127253a9592a73be9bdfdf4ed7a                  NaN
# 99223  1adeb9d84d72fe4e337617733eb85149                  NaN
#
#                                   review_comment_message Primary Category  \
# 0      😡😡😡😡😡👎👎👎👎👎\r\nEmpresa sem compromisso com o cl...          Company
# 1              😍😍👧💅 amei e chegou até antes do esperodo          Positive
# ...

# %%
concated.to_csv('categorized_reviews.csv',index = False)

# %% [markdown]
# ## 4) Reviews With Tile Only (No Comment)

# %%
title_categorized = pd.read_csv(r'C:\Users\sas33\OneDrive\Desktop\Data Analytics\Data Sprint\Raw Data\Reviews categories\Title_categorized.csv')

# %%
reviews_with_title = concated[(concated['review_comment_title'].isnull() == False) & (concated['review_comment_message'].isnull() == True)]

# %%
reviews_with_title.reset_index(inplace = True)

# %%
title = list(reviews_with_title['review_comment_title'].values)

# %%
title_categorized.columns = ['index', 'Primary Category', 'Secondary Category']

# %%
title_categorized.drop('index', axis=1 , inplace=True)

# %%
title_categorized
# Out:
#      Primary Category Secondary Category
# 0            Positive             Others
# 1       Missing Items         Wrong Item
# 2            Delivery           Positive
# 3            Positive             Others
# 4            Positive             Others
# ...               ...                ...
# 1724         Positive           Delivery
# 1725         Positive             Others
# 1726         Positive             Others
# 1727         Positive             Others
# 1728         Delivery            Deffect
#
# [1729 rows x 2 columns]

# %%
title_categorized = pd.concat([reviews_with_title,title_categorized],axis=1)

# %%
title_categorized
# Out:
#       index                         review_id       review_comment_title  \
# 0     41007  1edd1a85161468a77e5fcb165be9b294                      Ótimo
# 1     41039  352609f0f2d34ce5d3b8de817ee948d5      Não recebi o produto.
# 2     41109  a89a2b0c2014bc49a0f87f1eedb7b269  Entrega antes do previsto
# 3     41112  cdc5c81bd9377ccbf9cb95f05648c31b                  Recomendo
# 4     41266  b50001aa0bbd7557c4ad80eee167a2a1                     Ótimo
# ...     ...                               ...                        ...
# 1724  99108  8b46f9e835a1644a414a9753b1d9539d                  Excelente
# 1725  99125  3103d2a4e5556d9c00c29e820958b5e7           Super satisfeito
# 1726  99138  451849d56168ddedbe4d4ef3749af6ea                  muito bom
# 1727  99190  d8ab64a06366d369a9cdbed694e7ee93            super recomendo
# 1728  99207  40743b46a0ee86375cedb95e82b78d75            OTIMA EMBALAGEM
#
#      review_comment_message Primary Category Secondary Category  \
# ...

# %%
title_categorized['Secondary Category'] = title_categorized['Primary Category']

# %%
title_categorized
# Out:
#       index                         review_id       review_comment_title  \
# 0     41007  1edd1a85161468a77e5fcb165be9b294                      Ótimo
# 1     41039  352609f0f2d34ce5d3b8de817ee948d5      Não recebi o produto.
# 2     41109  a89a2b0c2014bc49a0f87f1eedb7b269  Entrega antes do previsto
# 3     41112  cdc5c81bd9377ccbf9cb95f05648c31b                  Recomendo
# 4     41266  b50001aa0bbd7557c4ad80eee167a2a1                     Ótimo
# ...     ...                               ...                        ...
# 1724  99108  8b46f9e835a1644a414a9753b1d9539d                  Excelente
# 1725  99125  3103d2a4e5556d9c00c29e820958b5e7           Super satisfeito
# 1726  99138  451849d56168ddedbe4d4ef3749af6ea                  muito bom
# 1727  99190  d8ab64a06366d369a9cdbed694e7ee93            super recomendo
# 1728  99207  40743b46a0ee86375cedb95e82b78d75            OTIMA EMBALAGEM
#
#      review_comment_message Primary Category Secondary Category  \
# ...

# %%
title_categorized.columns = ['index','review_id', 'review_comment_title', 1,2,3, 'Primary Category','Secondary Category']

# %%
title_categorized.drop([1,2,3], axis=1 , inplace=True)

# %%
title_categorized
# Out:
#       index                         review_id       review_comment_title  \
# 0     41007  1edd1a85161468a77e5fcb165be9b294                      Ótimo
# 1     41039  352609f0f2d34ce5d3b8de817ee948d5      Não recebi o produto.
# 2     41109  a89a2b0c2014bc49a0f87f1eedb7b269  Entrega antes do previsto
# 3     41112  cdc5c81bd9377ccbf9cb95f05648c31b                  Recomendo
# 4     41266  b50001aa0bbd7557c4ad80eee167a2a1                     Ótimo
# ...     ...                               ...                        ...
# 1724  99108  8b46f9e835a1644a414a9753b1d9539d                  Excelente
# 1725  99125  3103d2a4e5556d9c00c29e820958b5e7           Super satisfeito
# 1726  99138  451849d56168ddedbe4d4ef3749af6ea                  muito bom
# 1727  99190  d8ab64a06366d369a9cdbed694e7ee93            super recomendo
# 1728  99207  40743b46a0ee86375cedb95e82b78d75            OTIMA EMBALAGEM
#
#      Primary Category Secondary Category
# 0            Positive           Positive
# ...

# %%
title_categorized.to_csv('categorized_titles.csv',index = False)
